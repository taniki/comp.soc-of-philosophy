# %%
# %matplotlib notebook  

from sklearn.decomposition import PCA
from sklearn.cross_decomposition import CCA

import networkx as nx
import pandas as pd
import numpy as np

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
G = nx.read_gexf("datasets/influences.gexf")

# %%
A = nx.to_numpy_matrix(G)

# %%
pca = PCA()
Z = pca.fit(A).transform(A)
Z = zip(*Z)

# %%
print len(pca.explained_variance_ratio_)

# i = 0
# s = 0
# while s < .99:
#   i = i + 1
#   s = np.sum(pca.explained_variance_ratio_[0:i])
  
#   print (i, s)

def plot_explained_vr(pca):
  (x, y) = zip(*list(enumerate(pca.explained_variance_ratio_)))
  
  y = [ np.sum(y[0:i]) for i, dummy in enumerate(y) ]
  
  fig = plt.figure()
  plt.plot(x, y)
  
  plt.show()

plot_explained_vr(pca)
# Out:
# 3358
# <img src="data:image/png;base64,...">

# %%
fig = plt.figure()
plt.scatter(Z[0], Z[1027])

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(Z[0], Z[1], Z[2])

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
df = pd.DataFrame(index=G.nodes())

df["z1"] = Z[0]
df["z2"] = Z[1]
df["z3"] = Z[2]

df.sort_values("z1", inplace=True)

df.head(50)
# Out:
#                                           z1        z2        z3
# Israr_Ahmed                        -0.126169  0.008341  0.000280
# Muhammad_Tahir                     -0.125927  0.008490  0.000328
# Javed_Ahmad_Ghamidi                -0.123644  0.007843 -0.000096
# Ghulam_Ali_Dihlawi                 -0.123364  0.008188  0.000312
# Sadat_Husaini                      -0.123238  0.008005  0.000264
# Haji_Dost_Muhammad_Qandhari        -0.122584  0.008101  0.000308
# Sayyad_Laal_Shah_Hamdani           -0.121684  0.007994  0.000302
# Anthony_Giddens,_Baron_Giddens     -0.119880  0.024274 -0.033115
# Muhammad_Usman_Damani              -0.119564  0.007745  0.000290
# François_Roustang                  -0.118420  0.023820 -0.032556
# Jean-Claude_Michéa                 -0.118420  0.023820 -0.032556
# Daniel_Cohn-Bendit                 -0.118420  0.023820 -0.032556
# Francisco_Varela                   -0.118420  0.023820 -0.032556
# Vincent_Descombes                  -0.118420  0.023820 -0.032556
# Hans_G._Furth                      -0.118420  0.023820 -0.032556
# Raphaël_Gély                       -0.118420  0.023820 -0.032556
# David_Ames_Curtis                  -0.118420  0.023820 -0.032556
# Danilo_Martuccelli                 -0.118420  0.023820 -0.032556
# Chris_Pallis                       -0.118420  0.023820 -0.032556
# Myriam_Revault_d'Allonnes          -0.118420  0.023820 -0.032556
# Nicole_Loraux                      -0.118420  0.023820 -0.032556
# Pierre_Vidal-Naquet                -0.118420  0.023820 -0.032556
# Theofanis_Tasis                    -0.118420  0.023820 -0.032556
# Claude_Lefort                      -0.118420  0.023820 -0.032556
# Jacques_Le_Goff                    -0.118420  0.023820 -0.032556
# Andreas_Kalyvas                    -0.118420  0.023820 -0.032556
# Georges_Lapassade                  -0.118420  0.023820 -0.032556
# Sophie_Klimis                      -0.118420  0.023820 -0.032556
# Laurent_Van_Eynde                  -0.118420  0.023820 -0.032556
# Yorgos_Oikonomou                   -0.118420  0.023820 -0.032556
# Frieder_Otto_Wolf                  -0.118420  0.023820 -0.032556
# René_Lourau                        -0.118420  0.023820 -0.032556
# E._P._Thompson                     -0.118420  0.023820 -0.032556
# Elias_Petropoulos                  -0.118420  0.023820 -0.032556
# Shimshon_Bichler                   -0.118420  0.023820 -0.032556
# Mathieu_Potte-Bonneville           -0.118420  0.023820 -0.032556
# Lorraine_Code                      -0.118420  0.023820 -0.032556
# Jonathan_Nitzan                    -0.118420  0.023820 -0.032556
# Johann_Pál_Arnason                 -0.118420  0.023820 -0.032556
# John_Thompson_(sociologist)        -0.118420  0.023820 -0.032556
# Vincent_de_Gaulejac                -0.118420  0.023820 -0.032556
# Edgar_Morin                        -0.118420  0.023820 -0.032556
# Sudipta_Kaviraj                    -0.118420  0.023820 -0.032556
# Graham_Ward_(theologian)           -0.118420  0.023820 -0.032556
# Marcel_Gauchet                     -0.118420  0.023820 -0.032556
# Harald_Wolf                        -0.118420  0.023820 -0.032556
# Robin_Hahnel                       -0.118420  0.023820 -0.032556
# Mirza_Mazhar_Jan-e-Janaan          -0.118330  0.007605  0.000282
# Sayyid_Ghulam_Hussain_Shah_Bukhari -0.118104  0.007793  0.000323
# Abdul_Quader_Molla                 -0.118061  0.007569  0.000189

# %%
df.tail(50)
# Out:
#                                      z1        z2        z3
# Ion_Dragoumis                  1.192918 -0.559894 -0.911085
# Giovanni_Gentile               1.198342  0.395272 -0.598512
# Damaris_Cudworth_Masham        1.199565 -2.396113 -0.563355
# Cornelius_Castoriadis          1.199587  0.296502 -1.416812
# Catherine_Malabou              1.205827  0.685684  0.194916
# Gottfried_Wilhelm_Leibniz      1.222833 -2.452834 -0.590228
# Leszek_Kołakowski              1.224622  0.763705  0.316435
# Juan_José_Sebreli              1.233607  0.856086  0.310605
# John_McDowell                  1.243974 -0.108425  0.743246
# Alfred_North_Whitehead         1.261306 -1.265261  0.743177
# Kostas_Axelos                  1.261412  0.984766 -0.783851
# Immanuel_Kant                  1.275194 -2.091894  0.375737
# Karl_Marx                      1.289819 -0.659949 -0.039330
# Xavier_Zubiri                  1.291926 -0.521271 -0.592131
# William_Desmond_(philosopher)  1.325088 -0.544502  0.366285
# Joseph_Dietzgen                1.325381  0.469264  0.667744
# Søren_Kierkegaard              1.325998 -0.406932  0.606610
# Benedetto_Croce                1.347021  0.655599  0.500021
# György_Lukács                  1.368202  0.963876  0.322257
# Slavoj_Žižek                   1.371311  0.852189 -0.791035
# Friedrich_Nietzsche            1.421026 -0.215107  1.311245
# Costanzo_Preve                 1.433872 -0.392594 -0.518546
# Judith_Butler                  1.434596  1.342448 -1.025513
# Gillian_Rose                   1.452782  0.395396  0.276963
# Marcel_Paquet                  1.481340  0.644556  0.231138
# Alasdair_MacIntyre             1.515037 -0.053218 -0.877911
# T._K._Seung                    1.519529  0.033941  0.574338
# Karl_Popper                    1.597377 -0.389197  0.927601
# Michael_Oakeshott              1.620609 -0.805236  0.512777
# Herbert_Marcuse                1.626267  1.078498 -0.132770
# Peter_Rollins                  1.645246  1.346098 -1.294755
# Allan_Bloom                    1.648364 -0.485074 -0.879820
# Michel_Aflaq__4                1.649057  0.705379  0.352544
# Leonardo_Polo                  1.684991 -0.378898  0.018251
# Gilles_Deleuze                 1.710664  0.443516  0.411562
# Charles_Taylor_(philosopher)   1.716631 -0.092317 -0.883582
# Karl_Jaspers                   1.724040  0.642434  0.260587
# Jürgen_Habermas                1.759664  1.168210  0.335592
# Jean-Paul_Sartre               1.796306  1.291671 -1.342204
# Georg_Wilhelm_Friedrich_Hegel  1.848736 -1.685908  1.024502
# Hans-Georg_Gadamer             1.904082 -0.495156 -0.062817
# Richard_J._Bernstein           1.920509  0.687492  0.289457
# Simone_de_Beauvoir             2.081901  1.054889 -0.204537
# Michael_Marder                 2.130968 -0.600794 -0.226694
# Theodor_W._Adorno              2.155209  1.114976  0.168955
# Boris_Groys                    2.337228  0.032551 -0.531624
# Leo_Strauss                    2.356254 -0.685890 -0.177409
# Simon_Critchley                2.464945  0.045068 -0.670834
# Martin_Heidegger               2.671536 -0.920451  0.419891
# Mário_Ferreira_dos_Santos      3.778563 -1.342523 -0.443463
