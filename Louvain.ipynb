# %%
import networkx as nx
import community

from IPython.display import display, HTML

# %%
G = nx.read_gexf("datasets/influences.gexf")

# %%
import community
partitions = community.best_partition(G.to_undirected())

# %%
def print_groups(communities):
    html = "<table>"

    for c, ps in communities.iteritems():
        html += "<tr><td style=\"width: 100px; text-align: center; \"><h3>group %s</h3></td><td>" % (c)
        html += ", ".join(map(lambda x: u"<a href=\"http://en.wikipedia.org/wiki/{0}\" target=\"_blank\">{0}</a>".format(x), ps))
        html += "</td></tr>"
    
    html += "</table>"

    display(HTML(html))
        
communities = {}
for k, v in partitions.iteritems():
    communities.setdefault(v, []).append(k)


print_groups(communities)
# Out:
# <table><tr><td style="width: 100px; text-align: center; "><h3>group 0</h3></td><td><a href="http://en.wikipedia.org/wiki/Muhammad_Mustafa_Jauhar" target="_blank">Muhammad_Mustafa_Jauhar</a>, <a href="http://en.wikipedia.org/wiki/Abu_Zayd_al-Balkhi" target="_blank">Abu_Zayd_al-Balkhi</a>, <a href="http://en.wikipedia.org/wiki/Muhammad" target="_blank">Muhammad</a>, <a href="http://en.wikipedia.org/wiki/Ibn_Dihya_al-Kalby" target="_blank">Ibn_Dihya_al-Kalby</a>, <a href="http://en.wikipedia.org/wiki/Ishaq_Ibn_Rahwayh" target="_blank">Ishaq_Ibn_Rahwayh</a>, <a href="http://en.wikipedia.org/wiki/Abdollah_Javadi-Amoli" target="_blank">Abdollah_Javadi-Amoli</a>, <a href="http://en.wikipedia.org/wiki/Al-Kindi" target="_blank">Al-Kindi</a>, <a href="http://en.wikipedia.org/wiki/Abd_Allah_al-Qaysi" target="_blank">Abd_Allah_al-Qaysi</a>, <a href="http://en.wikipedia.org/wiki/Tariq_Ramadan" target="_blank">Tariq_Ramadan</a>, <a href="http://en.wikipedia.org/wiki/Ibn_Hawqal" target="_blank">Ibn_Hawqal</a>, <a href="http://en.wikipedia.org/wiki/Al-Raghib_al-Isfahani" target="_blank">Al-Raghib_al-Isfahani</a>, <a href="http://en.wikipedia.org/wiki/Jalaleddin_Ashtiani" target="_blank">Jalaleddin_Ashtiani</a>, <a href="http://en.wikipedia.org/wiki/Jamal_ad-Din_al-Afghani" target="_blank">Jamal_ad-Din_al-Afghani</a>, <a href="http://en.wikipedia.org/wiki/Muhammad_Baqir_al-Sadr" target="_blank">Muhammad_Baqir_al-Sadr</a>, <a href="http://en.wikipedia.org/wiki/Al-Jahiz" target="_blank">Al-Jahiz</a>, <a href="http://en.wikipedia.org/wiki/Ruhollah_Khomeini" target="_blank">Ruhollah_Khomeini</a>, <a href="http://en.wikipedia.org/wiki/Abu_Abd_al-Rahman_Ibn_Aqil_al-Zahiri" target="_blank">Abu_Abd_al-Rahman_Ibn_Aqil_